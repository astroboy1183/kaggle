# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
train_path='../input/house-prices-advanced-regression-techniques/train.csv'
train=pd.read_csv(train_path,index_col=0)

# %%
train

# %%
description=train.describe()

# %%
description.shape

# %% [markdown]
# # 37 columns contain numerical values

# %%
null_values=dict(train.isnull().sum())

# %%
null_values

# %%
train['PoolQC'].unique()

# %%
train.shape

# %%
pd.set_option('display.max_rows',None)
pd.set_option('display.max_columns',None)

# %%
pd.get_option('display.max_rows')

# %%
train

# %%
null_values_list=list(null_values.items())

# %%
null_values_list

# %%
n=[]

for i in range(len(null_values_list)):
    if(null_values_list[i][1]!=0):
        n.append(null_values_list[i])

# %%
n=dict(n)

# %%
n.keys() #columns that have missing values.

# %%
train_sub=train[list(n.keys())] # Dataframe with columns containing only missing values.

# %%
train_sub

# %%
from sklearn.linear_model import LinearRegression

# %%
description_columns=list(description.columns)
train_sub_columns=list(train_sub.columns)
print(description_columns)
print(train_sub_columns)
ll=[]
for item in description_columns:
    if item in train_sub_columns:
        ll.append(item)
      
print(ll)

# %%
train_sub

# %%
train['LotFrontage']=train['LotFrontage'].fillna(train['LotFrontage'].mean())
train['MasVnrArea']=train['MasVnrArea'].fillna(train['MasVnrArea'].mean())
train['GarageYrBlt']=train['GarageYrBlt'].fillna(train['GarageYrBlt'].mean())

# %%
train[description.columns].isnull().sum()

# %%
features=description.columns[0:len(description.columns)-1]
target=description.columns[len(description.columns)-1]

# %%
X=train[features]
y=train[target]

# %%
from sklearn.linear_model import LinearRegression

model=LinearRegression()

# %%
model.fit(X,y)

# %%
test_path='../input/house-prices-advanced-regression-techniques/test.csv'
test=pd.read_csv(test_path,index_col=0)

# %%
t=test.describe()

# %%
features_test=t.columns
x=test[features_test]

# %%
test[list(t.columns)]

# %%
test[features_test].isnull().sum()

# %%
columns=dict(test[features_test].isnull().sum())

# %%
columns=list(columns.items())

# %%
columns

# %%
m=[]

for i in range(len(columns)):
    if(columns[i][1]!=0):
        m.append(columns[i][0])

# %%
for column in m:
    test[column]=test[column].fillna(test[column].mean())

# %%
test[features_test].isnull().sum()

# %%
x=test[features_test]

# %%
y_preds=model.predict(x)

# %%
test1=pd.read_csv(test_path)

# %%
output=pd.DataFrame({'id':test1['Id'],'SalePrice':y_preds})

# %%
output.to_csv('submission.csv',index=False)

# %%
model.score(x,y_preds)
